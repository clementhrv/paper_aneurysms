# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\terve\Documents\0-MINES\Projet_TRELLIS\clusters\clusters_tsne_mean.csv')
df = df.iloc[:, :-1]
df_sorted = df.sort_values(by='cluster')
for cluster_id in df_sorted['cluster'].unique():
    print(f"Cluster {cluster_id}:")
    print(df_sorted[df_sorted['cluster'] == cluster_id])
    print("\n" + "-"*40 + "\n")
# Out:
# Cluster 0:
#                               filename         x         y  cluster method
# 50    AllFields_Resultats_MESH_177.npz -0.290127 -1.084715        0   tsne
# 1   AllFields_Resultats_MESH_193-2.npz -0.014389 -2.253315        0   tsne
# 20    AllFields_Resultats_MESH_212.npz -1.204734 -1.481874        0   tsne
# 19    AllFields_Resultats_MESH_9-1.npz -0.150969 -0.788590        0   tsne
# 31    AllFields_Resultats_MESH_213.npz -1.131823 -2.119464        0   tsne
# 93   AllFields_Resultats_MESH_42-3.npz -1.162460 -0.431714        0   tsne
# 91   AllFields_Resultats_MESH_42-1.npz -0.265657  0.155443        0   tsne
# 39  AllFields_Resultats_MESH_144-2.npz  0.727167 -1.359675        0   tsne
# 42    AllFields_Resultats_MESH_209.npz -0.503152 -2.994855        0   tsne
# 14    AllFields_Resultats_MESH_199.npz  0.136752  0.205764        0   tsne
# 12  AllFields_Resultats_MESH_198-1.npz  1.145813 -0.221257        0   tsne
#
# ----------------------------------------
#
# Cluster 1:
#                                filename         x         y  cluster method
# 33    AllFields_Resultats_MESH_54-2.npz  5.573984  1.983774        1   tsne
# 43       AllFields_Resultats_MESH_2.npz  4.463218  1.984726        1   tsne
# 0     AllFields_Resultats_MESH_54-1.npz  4.894690  1.957150        1   tsne
# 103      AllFields_Resultats_MESH_1.npz  5.120283  3.361920        1   tsne
# 58     AllFields_Resultats_MESH_152.npz  6.247749  3.676451        1   tsne
# 61     AllFields_Resultats_MESH_208.npz  6.426206  1.802655        1   tsne
# 78      AllFields_Resultats_MESH_31.npz  5.375818  2.844428        1   tsne
# 96     AllFields_Resultats_MESH_121.npz  5.180797  1.351674        1   tsne
# 99   AllFields_Resultats_MESH_196-2.npz  6.792817  2.717151        1   tsne
# 100    AllFields_Resultats_MESH_153.npz  7.192485  2.040642        1   tsne
# 30     AllFields_Resultats_MESH_139.npz  5.621634  1.628832        1   tsne
# 26       AllFields_Resultats_MESH_6.npz  7.631247  3.320075        1   tsne
# 104    AllFields_Resultats_MESH_159.npz  4.182786  1.744936        1   tsne
# 6      AllFields_Resultats_MESH_214.npz  5.583824 -0.063637        1   tsne
# 23      AllFields_Resultats_MESH_26.npz  6.666318  1.430628        1   tsne
# 7       AllFields_Resultats_MESH_34.npz  6.222230  0.149263        1   tsne
#
# ----------------------------------------
#
# Cluster 2:
#                               filename         x         y  cluster method
# 64    AllFields_Resultats_MESH_155.npz -0.940106 -4.525423        2   tsne
# 11  AllFields_Resultats_MESH_163-1.npz -2.132775 -3.836071        2   tsne
# 49    AllFields_Resultats_MESH_189.npz -2.909869 -5.017872        2   tsne
# 66    AllFields_Resultats_MESH_217.npz -0.803093 -4.564642        2   tsne
# 68    AllFields_Resultats_MESH_194.npz -1.925721 -3.536816        2   tsne
# 13    AllFields_Resultats_MESH_205.npz -2.428536 -2.688833        2   tsne
# 70    AllFields_Resultats_MESH_136.npz -2.035790 -3.318978        2   tsne
# 56    AllFields_Resultats_MESH_165.npz -1.198550 -5.820031        2   tsne
# 88    AllFields_Resultats_MESH_140.npz -1.757087 -6.102078        2   tsne
# 71    AllFields_Resultats_MESH_134.npz -3.530184 -3.838678        2   tsne
# 94    AllFields_Resultats_MESH_178.npz -3.624020 -4.572393        2   tsne
# 75  AllFields_Resultats_MESH_182-3.npz -3.371103 -3.280167        2   tsne
# 77    AllFields_Resultats_MESH_171.npz -0.268427 -4.697921        2   tsne
# 18    AllFields_Resultats_MESH_164.npz -2.375830 -2.174583        2   tsne
# 85  AllFields_Resultats_MESH_182-1.npz -3.793558 -4.452784        2   tsne
# 36    AllFields_Resultats_MESH_158.npz -2.454242 -5.006085        2   tsne
# 27    AllFields_Resultats_MESH_191.npz -1.501017 -6.233607        2   tsne
# 22    AllFields_Resultats_MESH_192.npz -2.726727 -4.510476        2   tsne
#
# ----------------------------------------
#
# Cluster 3:
#                               filename         x         y  cluster method
# 86  AllFields_Resultats_MESH_119-2.npz  1.515440  2.899898        3   tsne
# 92    AllFields_Resultats_MESH_129.npz  1.304881  1.870603        3   tsne
# 15    AllFields_Resultats_MESH_206.npz  1.047561  1.483263        3   tsne
# 2   AllFields_Resultats_MESH_163-2.npz  2.260565  1.445810        3   tsne
# 80    AllFields_Resultats_MESH_195.npz  0.638546  2.631625        3   tsne
#
# ----------------------------------------
#
# Cluster 4:
#                                filename         x         y  cluster method
# 62      AllFields_Resultats_MESH_55.npz -1.279030  0.329385        4   tsne
# 74     AllFields_Resultats_MESH_117.npz -3.736254  2.393186        4   tsne
# 67     AllFields_Resultats_MESH_187.npz -1.049191  0.897786        4   tsne
# 69     AllFields_Resultats_MESH_204.npz -4.472278 -0.957440        4   tsne
# 63       AllFields_Resultats_MESH_3.npz -3.771749  0.909601        4   tsne
# 79     AllFields_Resultats_MESH_128.npz -3.639789  2.862291        4   tsne
# 53     AllFields_Resultats_MESH_151.npz -3.166613 -0.018284        4   tsne
# 82     AllFields_Resultats_MESH_138.npz -1.300663  1.722424        4   tsne
# 25   AllFields_Resultats_MESH_193-1.npz -2.729934  0.699901        4   tsne
# 101    AllFields_Resultats_MESH_120.npz -3.696710 -0.674923        4   tsne
# 35     AllFields_Resultats_MESH_210.npz -1.311897  1.071332        4   tsne
# 97    AllFields_Resultats_MESH_42-2.npz -2.609792 -0.788257        4   tsne
# 47      AllFields_Resultats_MESH_11.npz -4.567376  2.465477        4   tsne
# 98     AllFields_Resultats_MESH_172.npz -3.660349  2.595456        4   tsne
#
# ----------------------------------------
#
# Cluster 5:
#                               filename         x         y  cluster method
# 51    AllFields_Resultats_MESH_166.npz  3.055305  0.047831        5   tsne
# 9   AllFields_Resultats_MESH_182-2.npz  3.229827  1.363750        5   tsne
# 59    AllFields_Resultats_MESH_202.npz  1.659396  0.044805        5   tsne
# 29     AllFields_Resultats_MESH_28.npz  4.624920  0.141080        5   tsne
# 21  AllFields_Resultats_MESH_168-1.npz  1.943154  0.769547        5   tsne
# 34    AllFields_Resultats_MESH_148.npz  2.246240  0.867361        5   tsne
# 10    AllFields_Resultats_MESH_135.npz  4.454223 -0.339197        5   tsne
# 72    AllFields_Resultats_MESH_181.npz  2.666707  0.633343        5   tsne
# 38  AllFields_Resultats_MESH_196-1.npz  3.895342 -1.240722        5   tsne
# 54    AllFields_Resultats_MESH_188.npz  2.171778 -0.525808        5   tsne
# 41    AllFields_Resultats_MESH_203.npz  2.621524 -0.078555        5   tsne
# 45     AllFields_Resultats_MESH_23.npz  4.059341  1.029547        5   tsne
# 3     AllFields_Resultats_MESH_162.npz  3.620185 -0.881390        5   tsne
#
# ----------------------------------------
#
# Cluster 6:
#                               filename         x         y  cluster method
# 95    AllFields_Resultats_MESH_173.npz  5.998448 -2.785119        6   tsne
# 37    AllFields_Resultats_MESH_174.npz  5.353098 -2.403424        6   tsne
# 17     AllFields_Resultats_MESH_25.npz  5.961274 -2.330046        6   tsne
# 44  AllFields_Resultats_MESH_198-2.npz  4.525337 -3.730324        6   tsne
# 90    AllFields_Resultats_MESH_183.npz  5.507652 -3.025230        6   tsne
# 83    AllFields_Resultats_MESH_142.npz  5.681594 -0.753097        6   tsne
#
# ----------------------------------------
#
# Cluster 7:
#                               filename         x         y  cluster method
# 89  AllFields_Resultats_MESH_168-2.npz  8.494236  0.672134        7   tsne
# 24    AllFields_Resultats_MESH_197.npz  9.051789  1.739108        7   tsne
# 81    AllFields_Resultats_MESH_215.npz  7.817956 -0.505859        7   tsne
# 16    AllFields_Resultats_MESH_219.npz  7.925861 -0.250707        7   tsne
# 48     AllFields_Resultats_MESH_40.npz  7.840883  1.181841        7   tsne
# 84    AllFields_Resultats_MESH_160.npz  7.908989  1.046021        7   tsne
# 60    AllFields_Resultats_MESH_185.npz  9.459405  1.378328        7   tsne
# 52    AllFields_Resultats_MESH_157.npz  9.344215  2.150797        7   tsne
# 65    AllFields_Resultats_MESH_161.npz  7.263713  0.078381        7   tsne
#
# ----------------------------------------
#
# Cluster 8:
#                                filename         x         y  cluster method
# 57     AllFields_Resultats_MESH_175.npz  2.326267  4.138181        8   tsne
# 5      AllFields_Resultats_MESH_207.npz  3.014317  3.792626        8   tsne
# 73      AllFields_Resultats_MESH_44.npz  1.887749  3.506611        8   tsne
# 87     AllFields_Resultats_MESH_211.npz  1.570232  4.783496        8   tsne
# 40   AllFields_Resultats_MESH_119-1.npz  2.376777  4.377847        8   tsne
# 28      AllFields_Resultats_MESH_19.npz  3.039151  2.971850        8   tsne
# 102    AllFields_Resultats_MESH_180.npz  1.517557  4.389753        8   tsne
# 8    AllFields_Resultats_MESH_186-2.npz  1.970220  2.951328        8   tsne
#
# ----------------------------------------
#
# Cluster 9:
#                               filename         x         y  cluster method
# 4     AllFields_Resultats_MESH_170.npz  3.214266 -3.278906        9   tsne
# 46    AllFields_Resultats_MESH_137.npz  1.092283 -2.967817        9   tsne
# 76  AllFields_Resultats_MESH_186-1.npz  1.758502 -3.088180        9   tsne
# 32    AllFields_Resultats_MESH_167.npz  2.172547 -3.570747        9   tsne
# 55    AllFields_Resultats_MESH_200.npz  1.795509 -2.252764        9   tsne
#
# ----------------------------------------
